# %%
from astroplan.plots import plot_airmass, plot_sky
import matplotlib.pyplot as plt
from astropy.time import Time
from astroplan import Observer
from astropy.coordinates import EarthLocation, Angle
import astropy.units as u
from astropy.coordinates import SkyCoord
from astroplan import FixedTarget
import numpy as np
# %matplotlib inline
# Out:
# C:\Miniconda3\lib\site-packages\astropy\table\column.py:1096: MaskedArrayFutureWarning: setting an item on a masked array which has a shared mask will not copy the mask and also change the original mask array in the future.
# Check the NumPy 1.11 release notes for more information.
#   ma.MaskedArray.__setitem__(self, index, value)

# %%
import pandas as pd
from astropy.time import Time

# %%
longitude = 107.6
latitude = -6.8
times = '2017-09-12 00:00:00' #midnight UTC, for example input 2017-09-12 to output 2017-09-11 prediction

maxMag = 12
maxDur = 200

# %%
t = Time(times)
url = "http://var2.astro.cz/ETD/predictions.php?JDmidnight={:f}&delka={:f}&sirka={:f}".format(t.jd, longitude, latitude)
dfs = pd.read_html(url)
a = dfs[2][pd.notnull(dfs[2][0])]
a = a.reset_index(drop=True)
a.columns = a.iloc[0]
a = a[1:]
a = a.assign(beginUT=a['BEGIN(UT/h,A)'][:].str[:5])
a = a.assign(rasi=a['OBJECT'][:].str[-3:])
a['OBJECT'] = a['OBJECT'][:].str[:-3]
a = a.join(a['BEGIN(UT/h,A)'].str.split(',', 1, expand=True).rename(columns={0:'AltBegin', 1:'DirBegin'}))
a['AltBegin'] = a['AltBegin'][:].str[-3:]
a = a.drop('BEGIN(UT/h,A)', 1)
a = a.assign(Center=a['CENTER(DD.MM. UT/h,A)'][:].str[7:12])
a = a.join(a['CENTER(DD.MM. UT/h,A)'].str.split(',', 1, expand=True).rename(columns={0:'AltCen', 1:'DirCen'}))
a['AltCen'] = a['AltCen'][:].str[12:]
a = a.drop('CENTER(DD.MM. UT/h,A)', 1)
a = a.assign(End=a['END(UT/h,A)'][:].str[:5])
a = a.join(a['END(UT/h,A)'].str.split(',', 1, expand=True).rename(columns={0:'AltEnd', 1:'DirEnd'}))
a['AltEnd'] = a['AltEnd'][:].str[5:]
a = a.drop('END(UT/h,A)', 1)
a = a.join(a['ElementsCoords'].str.split(':', 2, expand=True).rename(columns={1:'RA', 2:'DEC'}))
a = a.drop('ElementsCoords', 1)
a = a.drop(0, 1)
a['RA'] = a['RA'][:].str[:13]
a['DEC'] = a['DEC'][:].str[1:]
a[['D(min)', 'V(MAG)', 'DEPTH(MAG)']] = a[['D(min)', 'V(MAG)', 'DEPTH(MAG)']].apply(pd.to_numeric)

# %%
a
# Out:
#         OBJECT   D(min)  V(MAG)  DEPTH(MAG) beginUT rasi AltBegin DirBegin  \
# 1   HD209458 b  184.200   7.650      0.0162   10:40  Peg      15°        E
# 2   WASP-112 b  172.610  13.300      0.0161   10:48  PsA      13°       SE
# 3    HATS-24 b  145.200  12.830      0.0183   11:47  Pav      37°        S
# 4   Kepler-6 b  240.000  13.800      0.0113   11:33  Cyg      31°        N
# 5    CoRoT-6 b  245.000  13.900      0.0151   11:32  Oph      74°       NE
# 6    HATS-34 b   93.300  13.849      0.0242   13:00  Tuc      18°       SE
# 7     WASP-8 b  264.400   9.790      0.0151   11:58  Scl      11°       SE
# 8    HAT-P-6 b  202.800  10.500      0.0094   12:47  And      15°       NE
# 9    HATS-11 b  261.900  14.018      0.0125   13:30  Sgr      71°       SW
# 10  CoRoT-11 b  150.054  12.940      0.0123   14:49  Ser      48°        W
# 11  HAT-P-23 b  130.750  12.430      0.0076   15:26  Del      56°       NW
# 12    WASP-7 b  214.000   9.500      0.0108   14:59  Mic      56°        S
# 13   WASP-76 b  221.620   9.500      0.0128   15:48  PSC      40°        E
# 14   WASP-33 b  163.000   8.300      0.0151   16:30  And      26°       NE
# 15   WASP-99 b  315.360  28.800      0.0044   15:37  Hor      21°       SE
# 16    KELT-1 b  153.245  10.700      0.0066   17:36  And      44°        N
# 17   WASP-50 b  108.400  11.550      0.0215   19:25  Eri      78°        E
# 18   WASP-32 b  145.000  11.300      0.0135   19:33  Psc      61°        W
# 19   WASP-23 b  143.700  12.680      0.0215   20:01  Pup      26°       SE
# 20  HAT-P-39 b  251.280  12.422      0.0101   19:41  Gem      19°        E
#
#    Center AltCen DirCen    End AltEnd DirEnd             RA           DEC
# 1   12:12    36°     NE  13:44    55°     NE     22 03 10DE     +18 53 04
# 2   12:14    32°     SE  13:40    48°     SE   22 37 57.43D   -35 09 13.9
# 3   12:59    34°      S  14:12    28°     SW   17 55 33.60D   -61 44 50.3
# 4   13:33    35°      N  15:33    27°     NW   19 47 20.9DE   +48 14 23.8
# 5   13:35    65°     NW  15:37    36°      W   18 44 17.42D   06 39 47.95
# 6   13:46    23°     SE  14:33    27°      S   00 03 05.88D   -62 28 09.6
# 7   14:10    38°     SE  16:22    59°     SE   23 59 36.07D   -35 01 52.9
# 8   14:28    30°     NE  16:10    40°      N   23 39 05.85D   +42 27 57.5
# 9   15:41    44°     SW  17:52    14°      W   19 17 36.24D   -22 23 23.7
# 10  16:04    30°      W  17:19    11°      W   18 42 44.95D   05 56 16.12
# 11  16:31    44°     NW  17:37    29°     NW   20 24 29.73D   +16 45 44.3
# 12  16:46    42°     SW  18:33    23°     SW   20 44 10.13D   -39 13 29.7
# 13  17:38    66°      E  19:29    80°     NW   01 46 31.86D   +02 42 02.0
# 14  17:51    38°     NE  19:13    45°      N   02 26 51.08D   +37 33 02.5
# 15  18:15    42°     SE  20:52    46°      S   02 39 35.44D   -50 00 28.8
# 16  18:53    40°      N  20:09    30°     NW   00 01 26.92D    39 23 01.7
# 17  20:19    88°      S  21:14    76°      W   02 54 45.14D  -10 53 52.93
# 18  20:45    43°      W  21:58    25°      W   00 15 50.81D   +01 12 02.0
# 19  21:13    39°     SE  22:25    49°     SE   06 44 30.50D   -42 45 41.2
# 20  21:47    38°     NE  23:52    61°     NE   07 35 01.97D   +17 49 48.3

# %%
a[(a['V(MAG)']<maxMag) & (a['D(min)']<maxDur)]
# Out:
#         OBJECT   D(min)  V(MAG)  DEPTH(MAG) beginUT rasi AltBegin DirBegin  \
# 1   HD209458 b  184.200    7.65      0.0162   10:40  Peg      15°        E
# 14   WASP-33 b  163.000    8.30      0.0151   16:30  And      26°       NE
# 16    KELT-1 b  153.245   10.70      0.0066   17:36  And      44°        N
# 17   WASP-50 b  108.400   11.55      0.0215   19:25  Eri      78°        E
# 18   WASP-32 b  145.000   11.30      0.0135   19:33  Psc      61°        W
#
#    Center AltCen DirCen    End AltEnd DirEnd             RA           DEC
# 1   12:12    36°     NE  13:44    55°     NE     22 03 10DE     +18 53 04
# 14  17:51    38°     NE  19:13    45°      N   02 26 51.08D   +37 33 02.5
# 16  18:53    40°      N  20:09    30°     NW   00 01 26.92D    39 23 01.7
# 17  20:19    88°      S  21:14    76°      W   02 54 45.14D  -10 53 52.93
# 18  20:45    43°      W  21:58    25°      W   00 15 50.81D   +01 12 02.0

# %%
location = EarthLocation.from_geodetic(longitude*u.deg, latitude*u.deg, 1300*u.m)
bosscha = Observer(location=location, name="Bosscha", timezone="Asia/Jakarta")

# %%
obj1 = FixedTarget.from_name(a['OBJECT'][1])

# %%
times = '2017-09-11 12:12:00'
t1 = Time(times)
plot_airmass(obj1, bosscha, t1)

# %%
observe_time = t1 + np.linspace(-4, 5, 10)*u.hour
plot_sky(obj1, bosscha, observe_time)

# %%
from astroplan.plots import plot_finder_image
ax, hdu = plot_finder_image(obj1)
# Out:
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv16632670525665.fits [Done]
